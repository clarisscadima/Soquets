# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

data = '''
[{"idDisk":3,"idClient":3,"diskName":"C:\\\\","totalSpace":104280879104,"usedSpace":50528120832,"freeSpace":53752758272,"lastUpdate":"2025-02-26T09:29:44.753"},
{"idDisk":4,"idClient":4,"diskName":"C:","totalSpace":107374182400,"usedSpace":53687091200,"freeSpace":53687091200,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":5,"idClient":5,"diskName":"D:","totalSpace":214748364800,"usedSpace":107374182400,"freeSpace":107374182400,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":6,"idClient":6,"diskName":"C:","totalSpace":536870912000,"usedSpace":268435456000,"freeSpace":268435456000,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":7,"idClient":7,"diskName":"D:","totalSpace":1073741824000,"usedSpace":536870912000,"freeSpace":536870912000,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":8,"idClient":8,"diskName":"C:","totalSpace":214748364800,"usedSpace":107374182400,"freeSpace":107374182400,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":9,"idClient":9,"diskName":"D:","totalSpace":536870912000,"usedSpace":268435456000,"freeSpace":268435456000,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":12,"idClient":12,"diskName":"C:\\\\","totalSpace":487132041216,"usedSpace":461768200192,"freeSpace":25363841024,"lastUpdate":"2025-02-26T13:51:31.030"},
{"idDisk":13,"idClient":13,"diskName":"C:\\\\","totalSpace":1001721761792,"usedSpace":908413177856,"freeSpace":93308583936,"lastUpdate":"2025-02-26T14:07:00.143"},
{"idDisk":14,"idClient":3,"diskName":"C:\\\\\\\\","totalSpace":104280879104,"usedSpace":60528120322,"freeSpace":43752758782,"lastUpdate":"2025-02-20T10:15:34"},
{"idDisk":15,"idClient":4,"diskName":"D:\\\\\\\\","totalSpace":214748364800,"usedSpace":120374812000,"freeSpace":94373552800,"lastUpdate":"2025-02-21T09:10:12"},
{"idDisk":16,"idClient":7,"diskName":"C:\\\\\\\\","totalSpace":107374182400,"usedSpace":60670912000,"freeSpace":46703270400,"lastUpdate":"2025-02-22T14:22:45"},
{"idDisk":17,"idClient":7,"diskName":"D:\\\\\\\\","totalSpace":53687091200,"usedSpace":32834585600,"freeSpace":20852505600,"lastUpdate":"2025-02-23T16:30:11"},
{"idDisk":18,"idClient":12,"diskName":"C:\\\\\\\\","totalSpace":487132041216,"usedSpace":261762800192,"freeSpace":225369241024,"lastUpdate":"2025-02-24T13:51:31"},
{"idDisk":19,"idClient":13,"diskName":"C:\\\\\\\\","totalSpace":1001721761792,"usedSpace":958413177856,"freeSpace":43308583936,"lastUpdate":"2025-02-25T17:00:00"},
{"idDisk":20,"idClient":3,"diskName":"D:\\\\\\\\","totalSpace":214748364800,"usedSpace":137481240000,"freeSpace":77267124800,"lastUpdate":"2025-02-26T11:21:56"}]
'''

plt.figure(figsize=(6, 4))
plt.plot(df['lastUpdate'], df['usedSpace'], marker='o', linestyle='-', color='b', label='Uso del disco')
plt.title('Uso del disco a lo largo del tiempo')
plt.xlabel('Fecha de actualización')
plt.ylabel('Uso del disco (en bytes)')

plt.xticks([])

plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

data = '''
[{"idDisk":3,"idClient":3,"diskName":"C:\\\\","totalSpace":104280879104,"usedSpace":50528120832,"freeSpace":53752758272,"lastUpdate":"2025-02-26T09:29:44.753"},
{"idDisk":4,"idClient":4,"diskName":"C:","totalSpace":107374182400,"usedSpace":53687091200,"freeSpace":53687091200,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":5,"idClient":5,"diskName":"D:","totalSpace":214748364800,"usedSpace":107374182400,"freeSpace":107374182400,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":6,"idClient":6,"diskName":"C:","totalSpace":536870912000,"usedSpace":268435456000,"freeSpace":268435456000,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":7,"idClient":7,"diskName":"D:","totalSpace":1073741824000,"usedSpace":536870912000,"freeSpace":536870912000,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":8,"idClient":8,"diskName":"C:","totalSpace":214748364800,"usedSpace":107374182400,"freeSpace":107374182400,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":9,"idClient":9,"diskName":"D:","totalSpace":536870912000,"usedSpace":268435456000,"freeSpace":268435456000,"lastUpdate":"2025-02-26T11:21:56.417"},
{"idDisk":12,"idClient":12,"diskName":"C:\\\\","totalSpace":487132041216,"usedSpace":461768200192,"freeSpace":25363841024,"lastUpdate":"2025-02-26T13:51:31.030"},
{"idDisk":13,"idClient":13,"diskName":"C:\\\\","totalSpace":1001721761792,"usedSpace":908413177856,"freeSpace":93308583936,"lastUpdate":"2025-02-26T14:07:00.143"},
{"idDisk":14,"idClient":3,"diskName":"C:\\\\\\\\","totalSpace":104280879104,"usedSpace":60528120322,"freeSpace":43752758782,"lastUpdate":"2025-02-20T10:15:34"},
{"idDisk":15,"idClient":4,"diskName":"D:\\\\\\\\","totalSpace":214748364800,"usedSpace":120374812000,"freeSpace":94373552800,"lastUpdate":"2025-02-21T09:10:12"},
{"idDisk":16,"idClient":7,"diskName":"C:\\\\\\\\","totalSpace":107374182400,"usedSpace":60670912000,"freeSpace":46703270400,"lastUpdate":"2025-02-22T14:22:45"},
{"idDisk":17,"idClient":7,"diskName":"D:\\\\\\\\","totalSpace":53687091200,"usedSpace":32834585600,"freeSpace":20852505600,"lastUpdate":"2025-02-23T16:30:11"},
{"idDisk":18,"idClient":12,"diskName":"C:\\\\\\\\","totalSpace":487132041216,"usedSpace":261762800192,"freeSpace":225369241024,"lastUpdate":"2025-02-24T13:51:31"},
{"idDisk":19,"idClient":13,"diskName":"C:\\\\\\\\","totalSpace":1001721761792,"usedSpace":958413177856,"freeSpace":43308583936,"lastUpdate":"2025-02-25T17:00:00"},
{"idDisk":20,"idClient":3,"diskName":"D:\\\\\\\\","totalSpace":214748364800,"usedSpace":137481240000,"freeSpace":77267124800,"lastUpdate":"2025-02-26T11:21:56"}]
'''

data = json.loads(data)

df = pd.DataFrame(data)

df_client_7 = df[df['idClient'] == 7]

plt.figure(figsize=(6, 4))
plt.plot(df_client_7['lastUpdate'], df_client_7['usedSpace'], marker='o', linestyle='-', color='g', label='Uso del disco')
plt.title('Uso del disco del cliente "Potosi" a lo largo del tiempo')
plt.xlabel('Fecha de actualización')
plt.ylabel('Uso del disco (en bytes)')

plt.xticks([])

plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()
